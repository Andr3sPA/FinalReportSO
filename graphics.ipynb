# %%
import pandas as pd
dfRaid0 = pd.read_csv('raid0.csv')
dfRaid1 = pd.read_csv('raid1.csv')
dfRaid5 = pd.read_csv('raid5.csv')
dfSingle = pd.read_csv('single.csv')

# %%
import matplotlib.pyplot as plt
raid0Write = dfRaid0['write'].mean()
raid1Write = dfRaid1['write'].mean()
raid5Write = dfRaid5['write'].mean()
singleWrite = dfSingle['write'].mean()
promedios = [raid0Write, raid1Write, raid5Write, singleWrite]
columnas = ['Raid 0', 'Raid 1', 'Raid 5', 'single Disk']

# Crear la gráfica de barras
plt.figure(figsize=(10, 6))
plt.bar(columnas, promedios, color=['blue', 'green', 'red', 'purple'])
plt.xlabel('Configuration')
plt.ylabel('Velocity I/O (KB/s)')
plt.title('Average of Write')
plt.show()

# %%
import matplotlib.pyplot as plt
raid0Read = dfRaid0['read'].mean()
raid1Read = dfRaid1['read'].mean()
raid5Read = dfRaid5['read'].mean()
singleRead = dfSingle['read'].mean()
promedios = [raid0Read, raid1Read, raid5Read, singleRead]
columnas = ['Raid 0', 'Raid 1', 'Raid 5', 'single Disk']

# Crear la gráfica de barras
plt.figure(figsize=(10, 6))
plt.bar(columnas, promedios, color=['blue', 'green', 'red', 'purple'])
plt.xlabel('Configuration')
plt.ylabel('Velocity I/O (KB/s)')
plt.title('Average of Read')
plt.show()

# %%
import matplotlib.pyplot as plt
raid0RandRead = dfRaid0['rand_read'].mean()
raid1RandRead = dfRaid1['rand_read'].mean()
raid5RandRead = dfRaid5['rand_read'].mean()
singleRandRead = dfSingle['rand_read'].mean()
promedios = [raid0RandRead, raid1RandRead, raid5RandRead, singleRandRead]
columnas = ['Raid 0', 'Raid 1', 'Raid 5', 'single Disk']

# Crear la gráfica de barras
plt.figure(figsize=(10, 6))
plt.bar(columnas, promedios, color=['blue', 'green', 'red', 'purple'])
plt.xlabel('Configuration')
plt.ylabel('Velocity I/O (KB/s)')
plt.title('Average of Random Read')
plt.show()

# %%
import matplotlib.pyplot as plt
raid0RandWrite = dfRaid0['rand_write'].mean()
raid1RandWrite = dfRaid1['rand_write'].mean()
raid5RandWrite = dfRaid5['rand_write'].mean()
singleRandWrite = dfSingle['rand_write'].mean()
promedios = [raid0RandWrite, raid1RandWrite, raid5RandWrite, singleRandWrite]
columnas = ['Raid 0', 'Raid 1', 'Raid 5', 'single Disk']

# Crear la gráfica de barras
plt.figure(figsize=(10, 6))
plt.bar(columnas, promedios, color=['blue', 'green', 'red', 'purple'])
plt.xlabel('Configuration')
plt.ylabel('Velocity I/O (KB/s)')
plt.title('Average of Random Write')
plt.show()
